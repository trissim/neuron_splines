# %%
import navis 
import numpy as np
import scipy
import utils
from scipy import interpolate
import pixiedust
# Out:
# WARNING : Module pyoctree not found. Falling back to scipy'sConvexHull for intersection calculations. (navis)
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3c53af146193> in <module>
#       2 import numpy as np
#       3 import scipy
# ----> 4 import utils
#       5 from scipy import interpolate
#       6 import pixiedust
#
# ModuleNotFoundError: No module named 'utils'

# %%
from scipy import interpolate
from simplification.cutil import *
get_segments = lambda neuron : [navis.subset_neuron(neuron,list(n)) for n in neuron.segments]
get_node = lambda neuron, node_id : neuron.nodes.loc[neuron.nodes['node_id'] == node_id] 
get_node_pos = lambda node : (np.float(node['x']),np.float(node['y']))
get_point_list = lambda segment : [get_node_pos(get_node(segment,node_id)) for node_id in segment.nodes['node_id']]

def plot_curve(interp_B):
    vis_config = VisMPL.VisConfig(legend=False, axes=False, figure_dpi=120)
    vis_obj = VisMPL.VisCurve2D(vis_config)
    interp_B.vis = vis_obj
    interp_B.render()

def get_spline(segment,tol=2,order=3,topology=True):
    pt_list = [(a,-1.0*b) for (a,b) in get_point_list(segment)]
    #seg[seg_num].plot2d()
    raw_pt_num = pt_list 
    if topology:
        simple_pt_list = simplify_coords_vwp(pt_list,tol)
    else:
        simple_pt_list = simplify_coords(pt_list,tol)
    interp_B = interpolate_curve(simple_pt_list,order)
    interp_B = interpolate_curve(simple_pt_list,order)
    return interp_B

def neuron_to_splines(neuron,tol=2,order=3):
    return [get_spline(segment,tol=tol,order=order) for segment in get_segments(neuron)]

# %%
from geomdl.fitting import interpolate_curve
from geomdl.fitting import approximate_curve
from geomdl.visualization import VisMPL
neuron = navis.from_swc('/home/levodextro/sd/School/Data/Microscopy/mardja_fc/NLMorphologyConverter/cnicswc/FC-A vs FC-7 plate 2_C01_s4_w1F6C80250-C491-4477-8F05-8FF7BC257943.swc')
segments = get_segments(neuron)
#plot_curve(get_spline(segments[3]))
neuron.plot2d()
for segment in get_segments(neuron):
    segment.plot2d()
    plot_curve(get_spline(segment,tol=1,order = 3))

# %%
neuron = navis.from_swc('/home/levodextro/sd/School/Data/Microscopy/mardja_fc/NLMorphologyConverter/cnicswc/FC-A vs FC-7 plate 2_C01_s4_w1F6C80250-C491-4477-8F05-8FF7BC257943.swc')
segments = get_segments(neuron)
for segment in get_segments(neuron):
    segment.plot2d()
    plot_curve(get_spline(segment,tol=5,order = 3))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-a30f41bfdb87> in <module>
#       3 for segment in get_segments(neuron):
#       4     segment.plot2d()
# ----> 5     plot_curve(get_spline(segment,tol=5,order = 3))
#       6
#
# <ipython-input-5-91992b41c8f3> in get_spline(segment, tol, order, topology)
#      20     else:
#      21         simple_pt_list = simplify_coords(pt_list,tol)
# ---> 22     interp_B = interpolate_curve(simple_pt_list,order)
#      23     interp_B = interpolate_curve(simple_pt_list,order)
#      24     return interp_B
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in interpolate_curve(points, degree, **kwargs)
#      42
#      43     # Do global interpolation
# ---> 44     matrix_a = _build_coeff_matrix(degree, kv, uk, points)
#      45     ctrlpts = linalg.lu_solve(matrix_a, points)
#      46
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in _build_coeff_matrix(degree, knotvector, params, points)
#     531     for i in range(num_points):
#     532         span = helpers.find_span_linear(degree, knotvector, num_points, params[i])
# --> 533         matrix_a[i][span-degree:span+1] = helpers.basis_function(degree, knotvector, span, params[i])
#     534
#     535     # Return coefficient matrix
#
# ~/.local/lib/python3.7/site-packages/geomdl/helpers.py in basis_function(degree, knot_vector, span, knot)
#     165         saved = 0.0
#     166         for r in range(0, j):
# --> 167             temp = N[r] / (right[r + 1] + left[j - r])
#     168             N[r] = saved + right[r + 1] * temp
#     169             saved = left[j - r] * temp
#
# ZeroDivisionError: float division by zero

# %%
neuron = navis.from_swc('/home/levodextro/sd/School/Data/Microscopy/mardja_fc/NLMorphologyConverter/cnicswc/FC-A vs FC-7 plate 2_C01_s4_w1F6C80250-C491-4477-8F05-8FF7BC257943.swc')
segments = get_segments(neuron)
for segment in get_segments(neuron):
    segment.plot2d()
    plot_curve(get_spline(segment,tol=1,topology=False,order = 3))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-281bb86152c1> in <module>
#       3 for segment in get_segments(neuron):
#       4     segment.plot2d()
# ----> 5     plot_curve(get_spline(segment,tol=1,topology=False,order = 3))
#       6
#
# <ipython-input-5-91992b41c8f3> in get_spline(segment, tol, order, topology)
#      20     else:
#      21         simple_pt_list = simplify_coords(pt_list,tol)
# ---> 22     interp_B = interpolate_curve(simple_pt_list,order)
#      23     interp_B = interpolate_curve(simple_pt_list,order)
#      24     return interp_B
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in interpolate_curve(points, degree, **kwargs)
#      42
#      43     # Do global interpolation
# ---> 44     matrix_a = _build_coeff_matrix(degree, kv, uk, points)
#      45     ctrlpts = linalg.lu_solve(matrix_a, points)
#      46
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in _build_coeff_matrix(degree, knotvector, params, points)
#     531     for i in range(num_points):
#     532         span = helpers.find_span_linear(degree, knotvector, num_points, params[i])
# --> 533         matrix_a[i][span-degree:span+1] = helpers.basis_function(degree, knotvector, span, params[i])
#     534
#     535     # Return coefficient matrix
#
# ~/.local/lib/python3.7/site-packages/geomdl/helpers.py in basis_function(degree, knot_vector, span, knot)
#     165         saved = 0.0
#     166         for r in range(0, j):
# --> 167             temp = N[r] / (right[r + 1] + left[j - r])
#     168             N[r] = saved + right[r + 1] * temp
#     169             saved = left[j - r] * temp
#
# ZeroDivisionError: float division by zero

# %%
neuron = navis.from_swc('/home/levodextro/sd/School/Data/Microscopy/mardja_fc/NLMorphologyConverter/cnicswc/FC-A vs FC-7 plate 2_C01_s4_w1F6C80250-C491-4477-8F05-8FF7BC257943.swc')
segments = get_segments(neuron)
for segment in get_segments(neuron):
    segment.plot2d()
    plot_curve(get_spline(segment,tol=5,topology=False,order = 3))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-2ba541ce59ea> in <module>
#       3 for segment in get_segments(neuron):
#       4     segment.plot2d()
# ----> 5     plot_curve(get_spline(segment,tol=5,topology=False,order = 3))
#       6
#
# <ipython-input-5-91992b41c8f3> in get_spline(segment, tol, order, topology)
#      20     else:
#      21         simple_pt_list = simplify_coords(pt_list,tol)
# ---> 22     interp_B = interpolate_curve(simple_pt_list,order)
#      23     interp_B = interpolate_curve(simple_pt_list,order)
#      24     return interp_B
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in interpolate_curve(points, degree, **kwargs)
#      42
#      43     # Do global interpolation
# ---> 44     matrix_a = _build_coeff_matrix(degree, kv, uk, points)
#      45     ctrlpts = linalg.lu_solve(matrix_a, points)
#      46
#
# ~/.local/lib/python3.7/site-packages/geomdl/fitting.py in _build_coeff_matrix(degree, knotvector, params, points)
#     531     for i in range(num_points):
#     532         span = helpers.find_span_linear(degree, knotvector, num_points, params[i])
# --> 533         matrix_a[i][span-degree:span+1] = helpers.basis_function(degree, knotvector, span, params[i])
#     534
#     535     # Return coefficient matrix
#
# ~/.local/lib/python3.7/site-packages/geomdl/helpers.py in basis_function(degree, knot_vector, span, knot)
#     165         saved = 0.0
#     166         for r in range(0, j):
# --> 167             temp = N[r] / (right[r + 1] + left[j - r])
#     168             N[r] = saved + right[r + 1] * temp
#     169             saved = left[j - r] * temp
#
# ZeroDivisionError: float division by zero
